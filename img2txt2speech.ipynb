# %% [markdown]
# <a href="https://colab.research.google.com/github/g7vind/Image-to-Speech/blob/main/img2txt2speech.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from transformers import pipeline
import requests
def imgtotxt(url):
    pipe = pipeline("image-to-text", model="Salesforce/blip-image-captioning-large")
    text = pipe(url)[0]["generated_text"]
    return text

# %%
import requests
from IPython.display import Audio

def txttospeech(message):
    API_URL = "https://api-inference.huggingface.co/models/espnet/kan-bayashi_ljspeech_vits"
    headers = {"Authorization": "Bearer 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"}
    payloads = {"inputs": message}

    # Assuming the API directly returns audio content
    response = requests.post(API_URL, headers=headers, json=payloads)

    # Play the audio directly
    return Audio(response.content, autoplay=False)

# %%
text = imgtotxt("photo.jpg")
txttospeech(text)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
